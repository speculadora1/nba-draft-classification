# %%
import pandas as pd

# %%
nba = pd.read_csv('../data/nba_stats_classified.csv')
ncaa = pd.read_csv('../data/ncaa_summary.csv')
combine = pd.read_csv('../data/combine_stats.csv')
id_map = pd.read_csv('../data/id_map.csv')

# %%
id_map_ = id_map[['pro_id', 'cbb_id']]
nba_ = nba[['player_id', 'name', 'classification']].drop_duplicates()

map_nba = pd.merge(id_map_, nba_, left_on = 'pro_id', right_on = 'player_id', how = 'inner')

map_nba.drop(['player_id'], axis = 1, inplace = True)

map_nba.head()
# Out:
#       pro_id            cbb_id            name classification
# 0  martike01   kenyon-martin-1   Kenyon Martin        Starter
# 1  swiftst01  stromile-swift-1  Stromile Swift    Role Player
# 2  milesda01               NaN    Darius Miles    Role Player
# 3  fizerma01    marcus-fizer-1    Marcus Fizer    Role Player
# 4  millemi01     mike-miller-1     Mike Miller        Starter

# %%
ncaa_to_nba = pd.merge(map_nba, ncaa, left_on = 'cbb_id', right_on = 'player_id', how = 'inner')

ncaa_to_nba.drop(['player_id'], axis = 1, inplace = True)

ncaa_to_nba['season'] = ncaa_to_nba['season'] + 1

ncaa_to_nba.rename(columns = {'season': 'draft_season'}, inplace = True)

ncaa_to_nba.head()
# Out:
#       pro_id             cbb_id             name classification  draft_season  \
# 0  martike01    kenyon-martin-1    Kenyon Martin        Starter          2000
# 1  swiftst01   stromile-swift-1   Stromile Swift    Role Player          2000
# 2  fizerma01     marcus-fizer-1     Marcus Fizer    Role Player          2000
# 3  millemi01      mike-miller-1      Mike Miller        Starter          2000
# 4  johnsde03  dermarr-johnson-1  DerMarr Johnson    Role Player          2000
#
#    assist_percentage    assists  block_percentage     blocks  box_plus_minus  \
# 0                NaN  44.317881               NaN  97.397351             NaN
# 1                NaN  28.327079               NaN  86.837953             NaN
# 2                NaN  39.048448               NaN  34.539310             NaN
# 3                NaN  83.001074               NaN  13.060866             NaN
# 4                NaN  45.000000               NaN  30.000000             NaN
#
#    ... true_shooting_percentage  turnover_percentage  turnovers  \
# 0  ...                 0.592391            13.114570  59.642384
# 1  ...                 0.601466            16.787548  75.374840
# 2  ...                 0.594890            10.562431  74.490862
# 3  ...                 0.584151            15.081633  70.515217
# 4  ...                 0.594000            12.000000  46.000000
#
#    two_point_attempts  two_point_percentage  two_pointers  usage_percentage  \
# 0          337.298013              0.573662    193.503311               NaN
# 1          287.752665              0.606385    179.642644               NaN
# 2          484.872063              0.562921    276.314476               NaN
# 3          208.881489              0.562878    117.334765               NaN
# 4          153.000000              0.575000     88.000000               NaN
#
#    win_shares  win_shares_per_40_minutes  num_seasons
# 0    8.271523                   0.366543            4
# 1    7.438934                   0.300672            2
# 2    8.178155                   0.274545            3
# 3    4.818260                   0.197698            2
# 4    4.800000                   0.218000            1
#
# [5 rows x 54 columns]

# %%
combine.drop(['position'], axis = 1, inplace = True)

combined_data = pd.merge(ncaa_to_nba, combine, left_on = ['name', 'draft_season'], right_on = ['player', 'season'], how = 'inner')

combined_data.drop(['player', 'season'], axis = 1, inplace = True)

combined_data.head()
# Out:
#       pro_id            cbb_id            name classification  draft_season  \
# 0  crawfja01  jamal-crawford-1  Jamal Crawford        Starter          2000
# 1  claxtsp01  speedy-claxton-1  Speedy Claxton        Starter          2000
# 2  harvedo01  donnell-harvey-1  Donnell Harvey    Role Player          2000
# 3  madsema01     mark-madsen-1     Mark Madsen           Bust          2000
# 4  langhda01      dan-langhi-1      Dan Langhi        Exclude          2000
#
#    assist_percentage     assists  block_percentage     blocks  box_plus_minus  \
# 0                NaN   76.000000               NaN  16.000000             NaN
# 1                NaN  177.680432               NaN   8.389454             NaN
# 2                NaN   37.000000               NaN  31.000000             NaN
# 3                NaN   21.080449               NaN  21.000000             NaN
# 4                NaN   27.106623               NaN   8.368212             NaN
#
#    ... standing_vertical  max_vertical  bench_press  body_fat  hand_length  \
# 0  ...               NaN           NaN          0.0       NaN          NaN
# 1  ...              36.0          42.5          6.0       NaN          NaN
# 2  ...              33.0          32.5         15.0       NaN          NaN
# 3  ...              30.5          33.5         13.0       NaN          NaN
# 4  ...              31.0          34.5         12.0       NaN          NaN
#
#    hand_width  height_shoes  standing_reach  weight  wingspan
# 0         NaN           NaN           102.5   175.0      82.0
# 1         NaN           NaN            94.5   166.0      72.0
# 2         NaN           NaN           105.5   220.0      84.5
# 3         NaN           NaN           104.5   236.5      84.5
# 4         NaN           NaN           104.0   197.5      80.0
#
# [5 rows x 67 columns]

# %%
combined_data['classification'].value_counts()
# Out:
# Exclude        288
# Role Player    163
# Starter        104
# All-Star        19
# Bust            17
# Name: classification, dtype: int64

# %%
num_players = len(combined_data)
bad_columns = []

for column in combined_data.columns:
    print(f'{column}: {combined_data[column].isna().sum()} missing values')
    
    # append column to list for removal if exceeds 25% missing data
    if combined_data[column].isna().sum() >= 0.25 * num_players:
        bad_columns.append(column)
    else:
        continue
        
combined_data.drop(bad_columns, axis = 1, inplace = True)

combined_data.head()
# Out:
# pro_id: 0 missing values
# cbb_id: 0 missing values
# name: 0 missing values
# classification: 0 missing values
# draft_season: 0 missing values
# assist_percentage: 87 missing values
# assists: 0 missing values
# block_percentage: 87 missing values
# blocks: 0 missing values
# box_plus_minus: 300 missing values
# conference: 0 missing values
# defensive_box_plus_minus: 300 missing values
# defensive_rebound_percentage: 260 missing values
# defensive_rebounds: 15 missing values
# defensive_win_shares: 0 missing values
# effective_field_goal_percentage: 0 missing values
# field_goal_attempts: 0 missing values
# field_goal_percentage: 0 missing values
# field_goals: 0 missing values
# free_throw_attempt_rate: 0 missing values
# free_throw_attempts: 0 missing values
# free_throw_percentage: 0 missing values
# free_throws: 0 missing values
# games_played: 0 missing values
# games_started: 14 missing values
# minutes_played: 0 missing values
# offensive_box_plus_minus: 300 missing values
# offensive_rebound_percentage: 260 missing values
# offensive_rebounds: 15 missing values
# offensive_win_shares: 0 missing values
# personal_fouls: 0 missing values
# player_efficiency_rating: 300 missing values
# points: 0 missing values
# points_produced: 260 missing values
# position: 0 missing values
# steal_percentage: 259 missing values
# steals: 0 missing values
# team_abbreviation: 0 missing values
# three_point_attempt_rate: 0 missing values
# three_point_attempts: 0 missing values
# three_point_percentage: 44 missing values
# three_pointers: 0 missing values
# total_rebound_percentage: 87 missing values
# total_rebounds: 0 missing values
# true_shooting_percentage: 0 missing values
# turnover_percentage: 0 missing values
# turnovers: 0 missing values
# two_point_attempts: 0 missing values
# two_point_percentage: 0 missing values
# two_pointers: 0 missing values
# usage_percentage: 87 missing values
# win_shares: 0 missing values
# win_shares_per_40_minutes: 0 missing values
# num_seasons: 0 missing values
# lane_agility: 74 missing values
# shuttle_run: 432 missing values
# three_quarter_sprint: 69 missing values
# standing_vertical: 64 missing values
# max_vertical: 66 missing values
# bench_press: 129 missing values
# body_fat: 71 missing values
# hand_length: 262 missing values
# hand_width: 262 missing values
# height_shoes: 99 missing values
# standing_reach: 2 missing values
# weight: 2 missing values
# wingspan: 1 missing values
#       pro_id            cbb_id            name classification  draft_season  \
# 0  crawfja01  jamal-crawford-1  Jamal Crawford        Starter          2000
# 1  claxtsp01  speedy-claxton-1  Speedy Claxton        Starter          2000
# 2  harvedo01  donnell-harvey-1  Donnell Harvey    Role Player          2000
# 3  madsema01     mark-madsen-1     Mark Madsen           Bust          2000
# 4  langhda01      dan-langhi-1      Dan Langhi        Exclude          2000
#
#    assist_percentage     assists  block_percentage     blocks    conference  \
# 0                NaN   76.000000               NaN  16.000000       big-ten
# 1                NaN  177.680432               NaN   8.389454  america-east
# 2                NaN   37.000000               NaN  31.000000           sec
# 3                NaN   21.080449               NaN  21.000000        pac-12
# 4                NaN   27.106623               NaN   8.368212           sec
#
#    ...  lane_agility  three_quarter_sprint  standing_vertical  max_vertical  \
# 0  ...           NaN                   NaN                NaN           NaN
# 1  ...         10.48                  3.06               36.0          42.5
# 2  ...         11.23                   NaN               33.0          32.5
# 3  ...         12.12                  3.46               30.5          33.5
# 4  ...         10.85                  3.24               31.0          34.5
#
#    bench_press  body_fat  height_shoes  standing_reach  weight  wingspan
# 0          0.0       NaN           NaN           102.5   175.0      82.0
# 1          6.0       NaN           NaN            94.5   166.0      72.0
# 2         15.0       NaN           NaN           105.5   220.0      84.5
# 3         13.0       NaN           NaN           104.5   236.5      84.5
# 4         12.0       NaN           NaN           104.0   197.5      80.0
#
# [5 rows x 56 columns]

# %%
# replace NAs with mean within player position
for column in combined_data.columns:
    try:
        combined_data[column].fillna(combined_data.groupby('position')[column].transform('mean'), inplace = True)
    except:
        continue

# %%
combined_data.to_csv('../data/nba_draftees.csv', index = False)
